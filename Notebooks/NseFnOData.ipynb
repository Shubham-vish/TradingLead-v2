# %%
import pandas as pd

# URL of the Excel file
url = 'https://archives.nseindia.com/content/nsccl/fao_participant_oi_06122023.csv'

# Read the Excel file into a pandas DataFrame
df = pd.read_csv(url, header=1)

# Display the first few rows of the DataFrame
df.head()
# Out:
#   Client Type  Future Index Long  Future Index Short  Future Stock Long  \
# 0      Client             162424              210767            1683872
# 1         DII              84033               48431             125641
# 2         FII             130109              107155            1406392
# 3         Pro              33432               43645             439189
# 4       TOTAL             409998              409998            3655094
#
#    Future Stock Short\t  Option Index Call Long  Option Index Put Long  \
# 0                240488                 3942496                4229699
# 1               2005424                       0                  74044
# 2               1227342                  986271                1224236
# 3                181840                 1322384                1352052
# 4               3655094                 6251151                6880030
#
#    Option Index Call Short  Option Index Put Short  Option Stock Call Long  \
# ...

# %%
df.head()
# Out:
#   Client Type  Future Index Long  Future Index Short  Future Stock Long  \
# 0      Client             176209              224843            1728825
# 1         DII              78626               48431             122762
# 2         FII             135508              103959            1384098
# 3         Pro              38826               51936             464829
# 4       TOTAL             429169              429169            3700514
#
#    Future Stock Short\t  Option Index Call Long  Option Index Put Long  \
# 0                251041                 3326337                3759411
# 1               2024536                       0                  73757
# 2               1236176                  755722                 979416
# 3                188761                 1286511                1326378
# 4               3700514                 5368570                6138961
#
#    Option Index Call Short  Option Index Put Short  Option Stock Call Long  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
import pandas as pd
from datetime import datetime, timedelta

# Function to generate URL for a given date
def create_url_for_date(date: datetime) -> str:
    base_url = 'https://archives.nseindia.com/content/nsccl/fao_participant_oi_'
    date_str = date.strftime('%d%m%Y')  # Format the date as DDMMYYYY
    return f"{base_url}{date_str}.csv"

# %%
yesterday = datetime.now() - timedelta(3)

# %%
create_url_for_date(yesterday)
# Out:
# 'https://archives.nseindia.com/content/nsccl/fao_participant_oi_08122023.csv'
