# %%
import pandas as pd

# Creating a DataFrame to organize the scenario analysis details
data = {
    "Scenario": [
        "Opening Market Behavior Analysis",
        "Market Response to Global Events",
        "Sector-specific Reactions",
        "Weekly Trend Analysis",
        "Pre and Post Holiday Analysis",
        "Expiry Day Dynamics",
        "Intraday Volatility Patterns",
        "Earnings Announcement Impacts",
        "Government Policy Announcements",
        "Inter-market Analysis",
        "Economic Data Releases",
        "Technical Indicator Scenarios",
        "Sentiment Analysis",
        "Historical Performance Analysis",
        "Impact of Monetary Policy",
        "Market Reaction to Catastrophic Events",
        "Liquidity Analysis",
        "Foreign Institutional Investor (FII) Activity"
    ],
    "Data Needed": [
        "Opening prices, previous day’s close, intraday highs and lows",
        "Dates and nature of global events, corresponding market performance data",
        "Sector-wise index performance, news, and events affecting sectors",
        "Daily market data (Monday to Friday)",
        "Market data before and after major holidays",
        "Market data on options/futures expiry days",
        "High-frequency intraday data",
        "Dates of earnings announcements, stock price data",
        "Dates of major policy announcements, market data",
        "Performance data of different global markets",
        "Dates of data releases, economic indicators, market data",
        "Historical price data for technical analysis",
        "Social media, news sentiment",
        "Long-term historical market data",
        "Dates of RBI policy announcements, market data",
        "Dates of events, market performance data",
        "Market liquidity data",
        "FII transaction data, market indices"
    ],
    "Starting Steps": [
        "Collect historical opening and closing price data, identify gap patterns, analyze subsequent performance",
        "Create a database of major global events and match them with market performance during those periods",
        "Track sectoral indices and correlate them with market-wide trends and specific news/events",
        "Analyze historical weekly data to identify patterns and trends",
        "Compile holiday dates and market data surrounding these dates for analysis",
        "Focus on the last Thursday of each month and analyze market trends on these days",
        "Collect intraday data and apply statistical analysis to identify volatility patterns",
        "Match earnings announcement dates with stock price movements",
        "Gather data on major policy announcements and analyze subsequent market behavior",
        "Collect and compare performance data of multiple global markets",
        "Track major economic indicators and their release dates, then analyze market reactions",
        "Apply technical analysis tools to historical data",
        "Use sentiment analysis tools to process news/social media data and correlate with market trends",
        "Analyze historical data to identify seasonal trends",
        "Collect data on RBI announcements and correlate with market changes",
        "Identify major catastrophic events and study market reaction during these periods",
        "Gather liquidity data and correlate with market trends",
        "Track FII inflows/outflows and correlate with market trends"
    ]
}

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# %%
file_path = 'path_to_your_file.xlsx'  # Replace with your desired file path
df.to_excel(file_path, index=False)
